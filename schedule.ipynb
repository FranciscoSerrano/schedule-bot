# %%
# Import Dependancies
import pandas as pd
import os
import plotly.express as px
import plotly

# %%
# Load in the data
file_to_load = os.path.join("All Shifts-Table 1.csv")
raw_schedule = pd.read_csv(file_to_load)
raw_schedule_df = pd.DataFrame(raw_schedule)

#Check for successful import
raw_schedule_df.head()
# Out:
#    GEO Country Role Start Date  Role Chat/Phone Shift Date  \
# 0  AMR  Canada          5/4/20  Mac+      Phone     9/3/20
# 1  AMR  Canada          5/4/20  Mac+      Phone     9/6/20
# 2  AMR  Canada          5/4/20  Mac+      Phone     9/9/20
# 3  AMR  Canada          5/4/20  Mac+      Phone    9/13/20
# 4  AMR  Canada          5/4/20  Mac+      Phone    9/15/20
#
#   Converted Time Zone Converted R@H Start Time (OOS Zone)  \
# 0             Central                             8:00 AM
# 1             Central                             8:00 AM
# 2             Central                             8:00 AM
# 3             Central                             8:00 AM
# 4             Central                             8:00 AM
#
#   Converted R@H End Time (OOS)  Retail @ Home Support Hours  ...  \
# 0                      5:00 PM                          8.0  ...
# 1                      5:00 PM                          8.0  ...
# 2                      5:00 PM                          8.0  ...
# 3                      5:00 PM                          8.0  ...
# 4                      5:00 PM                          8.0  ...
#
#                  Name  Location  Job Title Local SHIFT_DATE  \
# 0  Abdi, Magarsa Mume      R208     Genius           9/3/20
# 1  Abdi, Magarsa Mume      R208     Genius           9/6/20
# 2  Abdi, Magarsa Mume      R208     Genius           9/9/20
# 3  Abdi, Magarsa Mume      R208     Genius          9/13/20
# 4  Abdi, Magarsa Mume      R208     Genius          9/15/20
#
#   Local Full SHIFT_START_TIME Local Full SHIFT_END_TIME  \
# 0                     9:00 AM                   6:00 PM
# 1                     9:00 AM                   6:00 PM
# 2                     9:00 AM                   6:00 PM
# 3                     9:00 AM                   6:00 PM
# 4                     9:00 AM                   6:00 PM
#
#   Local EMPLOYEE_TIMEZONE     Market Team Language TIER 2 Flag
# 0                 Eastern  Canada Markets  English           N
# 1                 Eastern  Canada Markets  English           N
# 2                 Eastern  Canada Markets  English           N
# 3                 Eastern  Canada Markets  English           N
# 4                 Eastern  Canada Markets  English           N
#
# [5 rows x 23 columns]

# %%
# Drop the coloumns that arent needed.
raw_schedule_df = raw_schedule_df[["Team Manager", "Name", "Local SHIFT_DATE", "Local Full SHIFT_START_TIME", "Local Full SHIFT_END_TIME"]]
raw_schedule_df.head()

# %%
raw_schedule_df.dtypes

# %%
# Adds two new columns 'Start_Shift' and 'End Shift'
# This creates a start and end of a shift as a datetime object for charting.  
raw_schedule_df['Start_Shift'] = pd.to_datetime(raw_schedule_df['Local SHIFT_DATE'] + ' ' + raw_schedule_df['Local Full SHIFT_START_TIME'])
raw_schedule_df['End_Shift'] = pd.to_datetime(raw_schedule_df['Local SHIFT_DATE'] + ' ' + raw_schedule_df['Local Full SHIFT_END_TIME'])

raw_schedule_df.head()

# %%
# Asks Team Manager for input to get their name as it appears in the CSV file
print("Hey there, I'm a bot that can generate an interactive schedule chart for you!\n")
manager_name = input("Please enter your name exactly as it appears in the Spreadsheet: ")

# %%
# Creates a new data frame with only the team members from a specific manager.
manager_team_df = raw_schedule_df.loc[raw_schedule_df['Team Manager'] == manager_name]

manager_team_df.reset_index()

# %%
# Creates the schecule chart using the Manager Team dataframe

schedule = px.timeline(manager_team_df, x_start="Start_Shift", x_end="End_Shift", y="Name")
schedule.update_yaxes(autorange="reversed") # otherwise tasks are listed from the bottom up


#Save Schedule as HTML for interactive Chart
plotly.offline.plot(schedule, filename='team_schedule.html')
